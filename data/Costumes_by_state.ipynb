# %%
import pandas as pd

url = "https://www.attsavings.com/resources/entertainment/popular-halloween-costume-in-your-state/"
tables = pd.read_html(url)

# %%
len(tables)
# Out:
# 1

# %%
df = tables[0]

# %%
df
# Out:
#                        0                       1
# 0                  State    Most Popular Costume
# 1                Alabama            Mickey Mouse
# 2                 Alaska               Pennywise
# 3                Arizona                Deadpool
# 4               Arkansas            Mickey Mouse
# 5             California                 Unicorn
# 6               Colorado               Star Wars
# 7            Connecticut                Catwoman
# 8               Delaware              Poison Ivy
# 9   District of Columbia         Stranger Things
# 10               Florida                Baywatch
# 11               Georgia           Storm Trooper
# 12                Hawaii                   Moana
# 13                 Idaho                Deadpool
# 14              Illinois           Mickey Mouses
# 15               Indiana            Mickey Mouse
# 16                  Iowa                Superman
# 17                Kansas               Wolverine
# ...

# %%
df.columns = df.iloc[0]
df = df.drop(df.index[0])
df
# Out:
# 0                  State    Most Popular Costume
# 1                Alabama            Mickey Mouse
# 2                 Alaska               Pennywise
# 3                Arizona                Deadpool
# 4               Arkansas            Mickey Mouse
# 5             California                 Unicorn
# 6               Colorado               Star Wars
# 7            Connecticut                Catwoman
# 8               Delaware              Poison Ivy
# 9   District of Columbia         Stranger Things
# 10               Florida                Baywatch
# 11               Georgia           Storm Trooper
# 12                Hawaii                   Moana
# 13                 Idaho                Deadpool
# 14              Illinois           Mickey Mouses
# 15               Indiana            Mickey Mouse
# 16                  Iowa                Superman
# 17                Kansas               Wolverine
# 18              Kentucky               Superhero
# ...

# %%
df.to_csv('/Users/marianachavez/Desktop/Project 2/costumes_by_states.csv', index=False)
